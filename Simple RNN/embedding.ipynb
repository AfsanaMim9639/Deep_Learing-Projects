# %%
from tensorflow.keras.preprocessing.text import one_hot

# %%
sent=[
    'the glass of milk',
    'the glass of juice',
    'the cup pf tea',
    'I am a developer',
    'I am oaky',
    'I have no problem with my life',
    'Evreything is going well'
]

# %%
sent
# Out:
# ['the glass of milk',
#  'the glass of juice',
#  'the cup pf tea',
#  'I am a developer',
#  'I am oaky',
#  'I have no problem with my life',
#  'Evreything is going well']

# %%
voc_size=10000

# %%
one_hot_rep=[one_hot(words,voc_size)for words in sent]

# %%
one_hot_rep
# Out:
# [[2023, 5633, 6121, 2112],
#  [2023, 5633, 6121, 4009],
#  [2023, 7216, 6395, 7938],
#  [1291, 7323, 6226, 3671],
#  [1291, 7323, 3183],
#  [1291, 5045, 2793, 4152, 3843, 1508, 4412],
#  [4985, 5484, 461, 6268]]

# %%
from tensorflow.keras.layers import Embedding
from tensorflow.keras.utils import pad_sequences
from tensorflow.keras.models import Sequential

# %%
import numpy as np

# %%
sent_length=8
embedded_docs=pad_sequences(one_hot_rep,padding='pre',maxlen=sent_length)
print(embedded_docs)
# Out:
# [[   0    0    0    0 2023 5633 6121 2112]
#  [   0    0    0    0 2023 5633 6121 4009]
#  [   0    0    0    0 2023 7216 6395 7938]
#  [   0    0    0    0 1291 7323 6226 3671]
#  [   0    0    0    0    0 1291 7323 3183]
#  [   0 1291 5045 2793 4152 3843 1508 4412]
#  [   0    0    0    0 4985 5484  461 6268]]

# %%
dim=10

# %%
model = Sequential()
model.add(Embedding(input_dim=voc_size, output_dim=dim, input_length=sent_length))
model.compile(optimizer='adam', loss='mse')
# Out:
# WARNING:tensorflow:From c:\Users\roger\anaconda3\envs\venv\lib\site-packages\keras\src\optimizers\__init__.py:309: The name tf.train.Optimizer is deprecated. Please use tf.compat.v1.train.Optimizer instead.

# %%
model.summary()
# Out:
# Model: "sequential_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 8, 10)             100000
#
# =================================================================
# Total params: 100000 (390.62 KB)
# Trainable params: 100000 (390.62 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
model.predict(embedded_docs)
# Out:
# 1/1 [==============================] - 0s 428ms/step
# array([[[-0.03484048,  0.02022039, -0.04064518, -0.00567522,
#           0.02437428,  0.04951308, -0.00360025, -0.01682439,
#           0.03097996, -0.03030583],
#         [-0.03484048,  0.02022039, -0.04064518, -0.00567522,
#           0.02437428,  0.04951308, -0.00360025, -0.01682439,
#           0.03097996, -0.03030583],
#         [-0.03484048,  0.02022039, -0.04064518, -0.00567522,
#           0.02437428,  0.04951308, -0.00360025, -0.01682439,
#           0.03097996, -0.03030583],
#         [-0.03484048,  0.02022039, -0.04064518, -0.00567522,
#           0.02437428,  0.04951308, -0.00360025, -0.01682439,
#           0.03097996, -0.03030583],
#         [-0.00103979,  0.0284475 , -0.03434805, -0.04195438,
#          -0.01692721,  0.04200764, -0.01679211, -0.04467488,
#          -0.03451265,  0.04283651],
#         [ 0.01983878,  0.03775283,  0.01963404,  0.00219226,
#           0.04047172,  0.04847492,  0.0036888 ,  0.00138934,
#          -0.01334065, -0.01566272],
#         [ 0.04906887,  0.02973418,  0.02763555, -0.00977224,
#          -0.04355353,  0.03273873,  0.03503605, -0.045305  ,
#           0.02798801, -0.00400174],
#         [-0.02517843, -0.01856922, -0.01075298, -0.00376214,
#           0.03631163,  0.0121754 , -0.04505324, -0.01331178,
#          -0.04913364, -0.00581997]],
#
#        [[-0.03484048,  0.02022039, -0.04064518, -0.00567522,
#           0.02437428,  0.04951308, -0.00360025, -0.01682439,
#           0.03097996, -0.03030583],
#         [-0.03484048,  0.02022039, -0.04064518, -0.00567522,
#           0.02437428,  0.04951308, -0.00360025, -0.01682439,
#           0.03097996, -0.03030583],
#         [-0.03484048,  0.02022039, -0.04064518, -0.00567522,
#           0.02437428,  0.04951308, -0.00360025, -0.01682439,
#           0.03097996, -0.03030583],
#         [-0.03484048,  0.02022039, -0.04064518, -0.00567522,
#           0.02437428,  0.04951308, -0.00360025, -0.01682439,
#           0.03097996, -0.03030583],
#         [-0.00103979,  0.0284475 , -0.03434805, -0.04195438,
#          -0.01692721,  0.04200764, -0.01679211, -0.04467488,
#          -0.03451265,  0.04283651],
#         [ 0.01983878,  0.03775283,  0.01963404,  0.00219226,
#           0.04047172,  0.04847492,  0.0036888 ,  0.00138934,
#          -0.01334065, -0.01566272],
#         [ 0.04906887,  0.02973418,  0.02763555, -0.00977224,
#          -0.04355353,  0.03273873,  0.03503605, -0.045305  ,
#           0.02798801, -0.00400174],
#         [ 0.02656319, -0.04912121, -0.02903833,  0.03390602,
#           0.00757446,  0.02844315, -0.00138561,  0.01427758,
#          -0.01876694,  0.02383195]],
#
#        [[-0.03484048,  0.02022039, -0.04064518, -0.00567522,
#           0.02437428,  0.04951308, -0.00360025, -0.01682439,
#           0.03097996, -0.03030583],
#         [-0.03484048,  0.02022039, -0.04064518, -0.00567522,
#           0.02437428,  0.04951308, -0.00360025, -0.01682439,
#           0.03097996, -0.03030583],
#         [-0.03484048,  0.02022039, -0.04064518, -0.00567522,
#           0.02437428,  0.04951308, -0.00360025, -0.01682439,
#           0.03097996, -0.03030583],
#         [-0.03484048,  0.02022039, -0.04064518, -0.00567522,
#           0.02437428,  0.04951308, -0.00360025, -0.01682439,
#           0.03097996, -0.03030583],
#         [-0.00103979,  0.0284475 , -0.03434805, -0.04195438,
#          -0.01692721,  0.04200764, -0.01679211, -0.04467488,
#          -0.03451265,  0.04283651],
#         [-0.01687304,  0.00624863,  0.04486147,  0.04853452,
#           0.01243313,  0.02741307, -0.02930046, -0.00907017,
#           0.04035628, -0.00693333],
#         [-0.01058123, -0.04218382,  0.00204917,  0.04056451,
#          -0.04745051, -0.02963705, -0.01033807, -0.02309265,
#          -0.03533012,  0.0077685 ],
#         [-0.02794225, -0.03398462,  0.00064117, -0.0050234 ,
#          -0.0355471 , -0.03696213, -0.01192571,  0.04155931,
#          -0.02501634,  0.00545665]],
#
#        [[-0.03484048,  0.02022039, -0.04064518, -0.00567522,
#           0.02437428,  0.04951308, -0.00360025, -0.01682439,
#           0.03097996, -0.03030583],
#         [-0.03484048,  0.02022039, -0.04064518, -0.00567522,
#           0.02437428,  0.04951308, -0.00360025, -0.01682439,
#           0.03097996, -0.03030583],
#         [-0.03484048,  0.02022039, -0.04064518, -0.00567522,
#           0.02437428,  0.04951308, -0.00360025, -0.01682439,
#           0.03097996, -0.03030583],
#         [-0.03484048,  0.02022039, -0.04064518, -0.00567522,
#           0.02437428,  0.04951308, -0.00360025, -0.01682439,
#           0.03097996, -0.03030583],
#         [ 0.04293858,  0.04517852, -0.03017966,  0.01426903,
#          -0.0111483 , -0.04422069, -0.04768246,  0.01026555,
#          -0.04771018,  0.00022159],
#         [ 0.02057326, -0.03395274, -0.03450089,  0.03021303,
#          -0.04149694,  0.04187426, -0.03275834, -0.02877565,
#          -0.01926353, -0.04703936],
#         [ 0.04649819,  0.00262207, -0.02726828, -0.04708424,
#          -0.04811596,  0.00542349, -0.04101495, -0.03803392,
#          -0.0388239 , -0.0449925 ],
#         [ 0.01157343,  0.02142874,  0.03440166, -0.02004473,
#           0.03943962,  0.00868813, -0.03026521,  0.04592966,
#          -0.01483787, -0.01276831]],
#
#        [[-0.03484048,  0.02022039, -0.04064518, -0.00567522,
#           0.02437428,  0.04951308, -0.00360025, -0.01682439,
#           0.03097996, -0.03030583],
#         [-0.03484048,  0.02022039, -0.04064518, -0.00567522,
#           0.02437428,  0.04951308, -0.00360025, -0.01682439,
#           0.03097996, -0.03030583],
#         [-0.03484048,  0.02022039, -0.04064518, -0.00567522,
#           0.02437428,  0.04951308, -0.00360025, -0.01682439,
#           0.03097996, -0.03030583],
#         [-0.03484048,  0.02022039, -0.04064518, -0.00567522,
#           0.02437428,  0.04951308, -0.00360025, -0.01682439,
#           0.03097996, -0.03030583],
#         [-0.03484048,  0.02022039, -0.04064518, -0.00567522,
#           0.02437428,  0.04951308, -0.00360025, -0.01682439,
#           0.03097996, -0.03030583],
#         [ 0.04293858,  0.04517852, -0.03017966,  0.01426903,
#          -0.0111483 , -0.04422069, -0.04768246,  0.01026555,
#          -0.04771018,  0.00022159],
#         [ 0.02057326, -0.03395274, -0.03450089,  0.03021303,
#          -0.04149694,  0.04187426, -0.03275834, -0.02877565,
#          -0.01926353, -0.04703936],
#         [ 0.00835801, -0.01733834,  0.01680333,  0.02978196,
#           0.03100565, -0.0440109 ,  0.0279392 , -0.01823069,
#           0.04868771, -0.03462843]],
#
#        [[-0.03484048,  0.02022039, -0.04064518, -0.00567522,
#           0.02437428,  0.04951308, -0.00360025, -0.01682439,
#           0.03097996, -0.03030583],
#         [ 0.04293858,  0.04517852, -0.03017966,  0.01426903,
#          -0.0111483 , -0.04422069, -0.04768246,  0.01026555,
#          -0.04771018,  0.00022159],
#         [ 0.00933248,  0.02119862,  0.04877658, -0.00747974,
#          -0.03448839, -0.00186002,  0.04980525, -0.01596614,
#           0.01558188,  0.03846001],
#         [-0.02475795, -0.04198239, -0.02081381, -0.03227878,
#          -0.01839245, -0.0064975 , -0.04866908, -0.02526829,
#          -0.02706027,  0.02476069],
#         [ 0.03950122, -0.03083763, -0.00606034, -0.00356265,
#          -0.00099735,  0.04412856,  0.02160046, -0.03029954,
#           0.03719148, -0.01016086],
#         [ 0.04742906,  0.01617508, -0.0412487 ,  0.01709858,
#           0.01006608,  0.03517666,  0.04296566, -0.03762479,
#          -0.03528274, -0.0123623 ],
#         [-0.04567354,  0.03550693, -0.02255001,  0.03320133,
#           0.00516282,  0.03981439, -0.00290747, -0.02231977,
#           0.03091364,  0.03194323],
#         [-0.0450221 ,  0.03964474, -0.01959288,  0.01984907,
#           0.01765598,  0.01158132,  0.00985563,  0.04588319,
#          -0.03771611,  0.02940008]],
#
#        [[-0.03484048,  0.02022039, -0.04064518, -0.00567522,
#           0.02437428,  0.04951308, -0.00360025, -0.01682439,
#           0.03097996, -0.03030583],
#         [-0.03484048,  0.02022039, -0.04064518, -0.00567522,
#           0.02437428,  0.04951308, -0.00360025, -0.01682439,
#           0.03097996, -0.03030583],
#         [-0.03484048,  0.02022039, -0.04064518, -0.00567522,
#           0.02437428,  0.04951308, -0.00360025, -0.01682439,
#           0.03097996, -0.03030583],
#         [-0.03484048,  0.02022039, -0.04064518, -0.00567522,
#           0.02437428,  0.04951308, -0.00360025, -0.01682439,
#           0.03097996, -0.03030583],
#         [ 0.03196878, -0.043647  ,  0.03538154,  0.04996622,
#          -0.0463868 ,  0.04927186,  0.02346689, -0.01885771,
#           0.02350214,  0.01783511],
#         [-0.00717459, -0.005942  , -0.01788007, -0.0293209 ,
#          -0.00949102,  0.01332663, -0.01544368, -0.04939703,
#           0.03336113, -0.04376186],
#         [-0.04041458, -0.00056269,  0.02139067, -0.03888742,
#          -0.0063494 ,  0.04196303,  0.0155575 , -0.0139424 ,
#          -0.00906603,  0.006837  ],
#         [-0.02066375,  0.03491992, -0.02054957, -0.03994961,
#           0.03061254, -0.01837475,  0.00482591, -0.02664571,
#          -0.02918453, -0.0142883 ]]], dtype=float32)
